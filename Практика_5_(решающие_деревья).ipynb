# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import math

class Trigonometry:
    @staticmethod
    def convert_to_radians(angle):
        if isinstance(angle, tuple) and angle[1] == 'degrees':
            return angle[0] * (math.pi / 180)
        else:
            return angle

    @staticmethod
    def cos(angle):
        angle_rad = Trigonometry.convert_to_radians(angle)
        return math.cos(angle_rad)

    @staticmethod
    def sin(angle):
        angle_rad = Trigonometry.convert_to_radians(angle)
        return math.sin(angle_rad)

    @staticmethod
    def tan(angle):
        angle_rad = Trigonometry.convert_to_radians(angle)
        return math.tan(angle_rad)

    @staticmethod
    def arcsin(value):
        return math.asin(value)

    @staticmethod
    def arccos(value):
        return math.acos(value)

    @staticmethod
    def arctan(value):
        return math.atan(value)

trig = Trigonometry()
angle_deg = (45, 'degrees')
angle_rad = 0.785398

print(f"Косинус {angle_deg[0]}°: {trig.cos(angle_deg)}")
print(f"Синус {angle_deg[0]}°: {trig.sin(angle_deg)}")
print(f"Тангенс {angle_deg[0]}°: {trig.tan(angle_deg)}")
print(f"Косинус в радианах: {trig.cos(angle_rad)}")
# Out:
# Косинус 45°: 0.7071067811865476
# Синус 45°: 0.7071067811865475
# Тангенс 45°: 0.9999999999999999
# Косинус в радианах: 0.7071068967259818

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
tree = ["a", ["b", ["d"], ["e"]], ["c", ["f"]]]
print("Корень дерева:", tree[0])
print("Левое поддерево:", tree[1])
print("Правое поддерево:", tree[2])
# Out:
# Корень дерева: a
# Левое поддерево: ['b', ['d'], ['e']]
# Правое поддерево: ['c', ['f']]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Tree:
    def __init__(self, data):
        self.left = None
        self.right = None
        self.data = data

    def insert(self, data):
        if data < self.data:
            if self.left is None:
                self.left = Tree(data)
            else:
                self.left.insert(data)
        elif data > self.data:
            if self.right is None:
                self.right = Tree(data)
            else:
                self.right.insert(data)
        else:
            print(f"Узел со значением {data} уже существует.")

    def print_tree(self, level=0):
        if self.right:
            self.right.print_tree(level + 1)
        print(' ' * 4 * level + '->', self.data)
        if self.left:
            self.left.print_tree(level + 1)
root = Tree(10)
root.insert(5)
root.insert(15)
root.insert(3)
root.insert(7)
root.insert(12)
root.insert(18)

print("Полное дерево:")
root.print_tree()
# Out:
# Полное дерево:
#         -> 18
#     -> 15
#         -> 12
# -> 10
#         -> 7
#     -> 5
#         -> 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report

# %%
X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])
target = [0, 0, 0, 1, 1, 1]
X_data = pd.DataFrame(X);
y = pd.DataFrame(target);
X_train, X_test, y_train, y_test = train_test_split(X_data, y, train_size=0.7, random_state=4)

# %%
model = DecisionTreeClassifier();
model.fit(X_train, y_train)
print(tree.plot_tree(model))
# Out:
# [Text(0.5, 0.75, 'x[1] <= 0.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'), Text(0.25, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'), Text(0.375, 0.5, 'True  '), Text(0.75, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'), Text(0.625, 0.5, '  False')]

# %%
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         2
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# %%
data = pd.read_csv('https://raw.githubusercontent.com/likarajo/petrol_consumption/master/data/petrol_consumption.csv')
X = data.drop(columns='Petrol_Consumption')
y = data['Petrol_Consumption']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=0)

# %%
model = DecisionTreeRegressor();
model.fit(X_train, y_train)
print(tree.plot_tree(model))
# Out:
# [Text(0.7407570422535211, 0.95, 'x[3] <= 0.667\nsquared_error = 15106.716\nsamples = 33\nvalue = 587.364'), Text(0.5378521126760564, 0.85, 'x[1] <= 4389.5\nsquared_error = 7159.498\nsamples = 29\nvalue = 556.138'), Text(0.6393045774647887, 0.8999999999999999, 'True  '), Text(0.31514084507042256, 0.75, 'x[0] <= 8.75\nsquared_error = 3117.472\nsamples = 18\nvalue = 600.167'), Text(0.16549295774647887, 0.65, 'x[1] <= 3731.5\nsquared_error = 2770.059\nsamples = 13\nvalue = 620.308'), Text(0.08450704225352113, 0.55, 'x[3] <= 0.613\nsquared_error = 798.0\nsamples = 3\nvalue = 687.0'), Text(0.056338028169014086, 0.45, 'x[1] <= 3687.0\nsquared_error = 56.25\nsamples = 2\nvalue = 706.5'), Text(0.028169014084507043, 0.35, 'squared_error = 0.0\nsamples = 1\nvalue = 699.0'), Text(0.08450704225352113, 0.35, 'squared_error = 0.0\nsamples = 1\nvalue = 714.0'), Text(0.11267605633802817, 0.45, 'squared_error = 0.0\nsamples = 1\nvalue = 648.0'), Text(0.24647887323943662, 0.55, 'x[3] <= 0.565\nsquared_
# ...

# %%
y_pred = model.predict(X_test)
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
# Out:
# MSE: 9916.4
